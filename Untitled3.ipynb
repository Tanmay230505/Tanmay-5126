# %%
from matplotlib import pyplot as plt
a%matplotlib inline
plt.scatter(df.Age, df['Invome($)'])
plt.xlabel('Age')
plt.ylabel['Income($)']
# Out:
#   File "<ipython-input-1-0e0215db28c0>", line 2
#     a%matplotlib inline
#                  ^
# SyntaxError: invalid syntax
